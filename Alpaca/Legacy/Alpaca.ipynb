# %% [markdown]
# <a href="https://colab.research.google.com/github/guilhermegranchopro/Prometheus/blob/main/Prometheus/Alpaca/Alpaca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Montar o Google Drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-2-ec727ec39611> in <cell line: 4>()
#       2
#       3 # Montar o Google Drive
# ----> 4 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     131   )
#     132   if ephemeral:
# --> 133     _message.blocking_request(
#     134         'request_auth',
#     135         request={'authType': 'dfs_ephemeral'},
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
import pandas as pd

# Caminho do arquivo Excel (.xlsx) na sua Google Drive
file_path = '/content/drive/MyDrive/AI Financial Analisys/Summer Project/Test/NYSE_and_NYSE_MKT_Trading_Units_Daily_File.xlsx'

# Leitura do arquivo Excel usando Pandas
df = pd.read_excel(file_path)

# Acessar e imprimir os valores da coluna B
coluna_symbol = df['Symbol']  # Seleciona a coluna B
print("Valores da Coluna Symbol:")
print(coluna_symbol)

# %%
pip install alpaca-trade-api
# Out:
# Collecting alpaca-trade-api
#   Downloading alpaca_trade_api-3.2.0-py3-none-any.whl.metadata (29 kB)
# Requirement already satisfied: pandas>=0.18.1 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api) (2.1.4)
# Requirement already satisfied: numpy>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api) (1.26.4)
# Requirement already satisfied: requests<3,>2 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api) (2.32.3)
# Collecting urllib3<2,>1.24 (from alpaca-trade-api)
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 625.6 kB/s eta 0:00:00
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api) (1.8.0)
# Collecting websockets<11,>=9.0 (from alpaca-trade-api)
#   Downloading websockets-10.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.4 kB)
# Collecting msgpack==1.0.3 (from alpaca-trade-api)
#   Downloading msgpack-1.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: aiohttp<4,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from alpaca-trade-api) (3.10.5)
# Collecting PyYAML==6.0.1 (from alpaca-trade-api)
#   Downloading PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting deprecation==2.1.0 (from alpaca-trade-api)
#   Downloading deprecation-2.1.0-py2.py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from deprecation==2.1.0->alpaca-trade-api) (24.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4,>=3.8.3->alpaca-trade-api) (4.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.18.1->alpaca-trade-api) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.18.1->alpaca-trade-api) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.18.1->alpaca-trade-api) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>2->alpaca-trade-api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>2->alpaca-trade-api) (3.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>2->alpaca-trade-api) (2024.7.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=0.18.1->alpaca-trade-api) (1.16.0)
# Downloading alpaca_trade_api-3.2.0-py3-none-any.whl (34 kB)
# Downloading deprecation-2.1.0-py2.py3-none-any.whl (11 kB)
# Downloading msgpack-1.0.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (323 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 323.7/323.7 kB 3.0 MB/s eta 0:00:00
# Downloading PyYAML-6.0.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (705 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 705.5/705.5 kB 12.9 MB/s eta 0:00:00
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 9.2 MB/s eta 0:00:00
# Downloading websockets-10.4-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 5.6 MB/s eta 0:00:00
# Installing collected packages: msgpack, websockets, urllib3, PyYAML, deprecation, alpaca-trade-api
#   Attempting uninstall: msgpack
#     Found existing installation: msgpack 1.0.8
#     Uninstalling msgpack-1.0.8:
#       Successfully uninstalled msgpack-1.0.8
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.0.7
#     Uninstalling urllib3-2.0.7:
#       Successfully uninstalled urllib3-2.0.7
#   Attempting uninstall: PyYAML
#     Found existing installation: PyYAML 6.0.2
#     Uninstalling PyYAML-6.0.2:
#       Successfully uninstalled PyYAML-6.0.2
# Successfully installed PyYAML-6.0.1 alpaca-trade-api-3.2.0 deprecation-2.1.0 msgpack-1.0.3 urllib3-1.26.20 websockets-10.4

# %%
import yfinance as yf

# Defina o símbolo da empresa
ticker_symbol = 'AAPL'  # Exemplo com Apple

# Obtenha os dados históricos
ticker_data = yf.Ticker(ticker_symbol)
historical_data = ticker_data.history(period='max')

# Obtenha a data da primeira cotação
first_trading_date = historical_data.index[0]
print(f"A empresa {ticker_symbol} começou a ser cotada na bolsa em:", first_trading_date.strftime("%Y-%m-%d"))

def get_start_date(symbol):
    ticker_data = yf.Ticker(symbol)
    historical_data = ticker_data.history(period='max')
    first_trading_date = historical_data.index[0]
    return first_trading_date
# Out:
# A empresa AAPL começou a ser cotada na bolsa em: 1980-12-12

# %%
import pandas as pd
from datetime import datetime, timedelta, timezone

# Obter a data e hora atuais
current_date_time = datetime.now()

# Formatar a data como string
current_date = current_date_time.strftime("%Y-%m-%d")
print(f"Hoje é: {current_date}")

def get_end_date(symbol):
    # Obter a data e hora atuais
    current_date_time = datetime.now()
    # Make start timezone aware
    current_date_time = current_date_time.replace(tzinfo=timezone.utc)
    return current_date_time
# Out:
# Hoje é: 2024-09-01

# %%
import alpaca_trade_api as tradeapi
import pandas as pd
import time
from datetime import datetime, timedelta

def alpaca_autentification():
    # Replace with your Alpaca API credentials
    API_KEY = 'AK1RX6F8W6QX207XPLDF'
    SECRET_KEY = 'WaPoTTxkQBGzC51LajCdyw8Pl6svbINa9eDu9TMK'
    BASE_URL = 'https://api.alpaca.markets'  # Use 'https://api.alpaca.markets' for live trading

    # Initialize the Alpaca API
    api = tradeapi.REST(API_KEY, SECRET_KEY, BASE_URL, api_version='v2')

    return api

# Function to fetch data in chunks to avoid rate limits
def fetch_data(symbol, start, end, timeframe, api):
    all_data = []
    current_start = start

    while current_start < end:
        current_end = current_start + timedelta(days=7)
        if current_end > end:
            current_end = end

        # Fetch the historical data
        bars = api.get_bars(
            symbol,
            timeframe,
            start=current_start.strftime('%Y-%m-%d'),
            end=current_end.strftime('%Y-%m-%d')
        ).df

        all_data.append(bars)
        current_start = current_end
        time.sleep(1)  # Adjust sleep interval based on rate limits

    return pd.concat(all_data)

# %%
def get_all_data(symbol = 'AAPL', max_period = True, start_date = '', end_date= '', timeframe = '1Min'):
    api = alpaca_autentification()

    if max_period and start_date == '' and end_date == '':
        start_date = get_start_date(symbol)
        end_date = get_end_date(symbol)
    elif start_date != '' and end_date != '':
        start_date = datetime.strptime(start_date, '%Y-%m-%d')
        end_date = datetime.strptime(end_date, '%Y-%m-%d')
    else:
        start_date = datetime(2022, 12, 31)
        end_date = datetime(2023, 12, 31)

    # Fetch the historical data
    apple_data = fetch_data(symbol, start_date, end_date, timeframe, api)
    return apple_data

# %%
# Function to prepare the data
def prepare_data(data, fisrt_marker, second_marker, third_marker):
    # Selecionar colunas relevantes e fazer uma cópia para evitar advertências
    data_selected = data[['close', 'high', 'low', 'trade_count', 'open', 'volume', 'vwap']].copy()

    # Calcular a média entre 'Open' e 'Close' usando .loc para evitar o SettingWithCopyWarning
    data_selected.loc[:, 'average_oc'] = data_selected[['open', 'close']].mean(axis=1)

    # Calcular a média entre 'High' e 'Low' usando .loc para evitar o SettingWithCopyWarning
    data_selected.loc[:, 'average_hl'] = data_selected[['high', 'low']].mean(axis=1)

    # Selecionar as colunas finais
    if third_marker != '':
        data_final = data_selected[[fisrt_marker, second_marker, third_marker]]
    else:
        data_final = data_selected[[fisrt_marker, second_marker]]

    return data_final

# %%
import numpy as np

# Função para criar as matrizes e os labels
def create_matrices(data_final, n = 12, fisrt_marker = 'volume', second_marker = 'vwap', third_marker = '', relative_fisrt_marker = True, relative_second_marker = False, relative_third_marker = False):
    num_rows = data_final.shape[0]
    num_matrices = num_rows // n  # Número de matrizes completas que podemos formar

    matrices = []
    matrices_y = []

    for i in range(num_matrices):
        start_idx = i * n
        end_idx = start_idx + n
        matrix = data_final.iloc[start_idx:end_idx].copy()

        if relative_fisrt_marker:
            # Calcular a soma da coluna de volume
            volume_sum = matrix[fisrt_marker].sum()

            # Tornar a coluna do volume relativa
            matrix[fisrt_marker] = matrix[fisrt_marker] / volume_sum

            # Converter para valores numpy e adicionar à lista de matrizes
            matrices.append(matrix.values)

        if relative_second_marker:
            # Calcular a soma da coluna de volume
            volume_sum = matrix[second_marker].sum()

            # Tornar a coluna do volume relativa
            matrix[second_marker] = matrix[second_marker] / volume_sum

            # Converter para valores numpy e adicionar à lista de matrizes
            matrices.append(matrix.values)

        if relative_third_marker:
            # Calcular a soma da coluna de volume
            volume_sum = matrix[third_marker].sum()

            # Tornar a coluna do volume relativa
            matrix[third_marker] = matrix[third_marker] / volume_sum

            # Converter para valores numpy e adicionar à lista de matrizes
            matrices.append(matrix.values)

        # Criar labels
        if i > 0:  # Ignorar a primeira matriz para alinhamento correto
            first_value = matrices[i][0, 1]
            last_value = matrices[i][n-1, 1]
            delta = last_value - first_value
            delta_bi = 1 if delta >= 0 else 0
            matrices_y.append(delta_bi)

    return matrices, matrices_y

def sort_matrices(matrices):
    # Ordenar as linhas de cada matriz por ordem decrescente da coluna Average (segunda coluna)
    matrices_x = []
    for matrix in matrices:
        sorted_indices = np.argsort(matrix[:, 1])[::-1]
        sorted_matrix = matrix[sorted_indices]
        matrices_x.append(sorted_matrix)
    return matrices_x

def tensor_creator(matrices_x, matrices_y):
    # Converter listas para arrays numpy
    matrices_x = np.array(matrices_x)
    matrices_y = np.array(matrices_y)
    return matrices_x, matrices_y

# %%
def get_dataset(company_data, n_rows, sort = True, fisrt_marker = 'volume', second_marker = 'vwap' ,
                third_marker = '', relative_fisrt_marker = True, relative_second_marker = False,
                relative_third_marker = False, decimals = ''):
    matrices_x = []
    matrices_y = []

    matrices_x, matrices_y = create_matrices(company_data, n_rows, fisrt_marker, second_marker, third_marker, relative_fisrt_marker, relative_second_marker, relative_third_marker)

    if sort:
        matrices_x = sort_matrices(matrices_x)

    # Remover a última matriz de matrices_x para alinhamento com matrices_y
    if matrices_x:
        matrices_x.pop()

    matrices_x, matrices_y = tensor_creator(matrices_x, matrices_y)

    if decimals != '':
        matrices_x = np.round(matrices_x, decimals = decimals)
    return matrices_x, matrices_y

# %%
from sklearn.model_selection import train_test_split

def split_dataset(matrices_x, matrices_y, LSTM = True):

    if LSTM:
        # Total de amostras
        n_samples = matrices_x.shape[0]

        # Índices para divisão
        train_size = int(0.6 * n_samples)  # 60% para treino
        val_size = int(0.2 * n_samples)    # 20% para validação
        test_size = n_samples - train_size - val_size  # 20% para teste

        # Dividir os dados sequencialmente
        X_train = matrices_x[:train_size]
        y_train = matrices_y[:train_size]

        X_val = matrices_x[train_size:train_size + val_size]
        y_val = matrices_y[train_size:train_size + val_size]

        X_test = matrices_x[train_size + val_size:]
        y_test = matrices_y[train_size + val_size:]
    else:
        # Dividir os dados em conjuntos de treinamento + validação e teste
        X_train_val, X_test, y_train_val, y_test = train_test_split(matrices_x, matrices_y, test_size=0.2, random_state=42)

        # Dividir o conjunto de treinamento + validação em treinamento e validação
        X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=42)  # 0.25 * 0.8 = 0.2

    return X_train, X_val, X_test, y_train, y_val, y_test

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, LSTM, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# Função para construir a rede neural
def build_model(input_shape, LSTM_boolean=True):
    model = Sequential()

    if LSTM_boolean:
        model.add(LSTM(64, input_shape=input_shape, return_sequences=True))
        model.add(Dropout(0.2))
        model.add(LSTM(64, return_sequences=False))
        model.add(Dropout(0.2))
    else:
        model.add(Flatten(input_shape=input_shape))
        model.add(Dense(64, activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.5))
        model.add(Dense(64, activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.5))

    model.add(Dense(1, activation='sigmoid'))

    # Compilando o modelo com uma taxa de aprendizado ajustada
    optimizer = Adam(learning_rate=0.001)
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    model.summary()

    return model

# %%
def model_training(model, X_train, X_val, X_test, y_train, y_val, y_test, epochs=5, batch_size=32):
    # Configuração do Early Stopping
    early_stopping = EarlyStopping(monitor='val_accuracy', patience=500, restore_best_weights=True)

    # Treinar o modelo
    history = model.fit(X_train, y_train, epochs = epochs, batch_size = batch_size, validation_data=(X_val, y_val), callbacks=[early_stopping])

    print()

    # Avaliar o modelo nos dados de teste
    test_loss, test_accuracy = model.evaluate(X_test, y_test)

    return history, test_loss, test_accuracy

# %%
# Plotar a precisão e a perda ao longo das épocas
import matplotlib.pyplot as plt

def graphics_analysis(history):

    # Precisão
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.title('Model Accuracy')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

    # Perda
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Model Loss')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# %% [markdown]
# As primeiras possibilidades de cada variável são aquelas as quais inicialmnete pensas-te que faziam mais sentido:
#
# * symbol = 'AAPL', (retira do ficheito execel, tens o código que extrai)
# * max_period = True, (podes ter erros por excesso de pedidos do API)
# * start_date = '', '2022-10-31', (1 ano funciona bem para test runs)
# * end_date = '', '2023-10-31', (1 ano funciona bem para test runs)
# * timeframe = '1Min', '5Min', (mais de 5Min parece perder sentido a teoria)
# * fisrt_marker = 'volume', 'close', 'high', 'low', 'trade_count', 'open', 'vwap', 'average_oc', 'average_hl', (a ideia inicial é ver o volume relativo, mas pode ser interessante estudar o trade_count)
# * second_marker = 'vwap', 'volume', 'close', 'high', 'low', 'trade_count', 'open', 'average_oc', 'average_hl', (a ideia inicial era ver a média entre o high e o low - 'average_hl', mas fica na duvida ver a média entre o open e o close - 'average_oc', pode também ser muito interessante investigar o vwap)
# * third_marker = '', 'volume', 'close', 'high', 'low', 'trade_count', 'open', 'vwap', 'average_oc', 'average_hl', (não pensas te em usar uma terceira coluna para criar as matrizes, mas se os resultados impiricos assim o provarem usa)
# * n_rows = 12, 10, 15, 30, 5, (pensa no timeframe quando fazes isso, o 12 pareceu ser o melhor em testes impiricos)
# * sort = True, (tens de pensar na sequencia temporal se faz sentido manter ou não)
# * relative_first_marker = True, (tens de pensar em que marker correspondente estás a usar, pensa se matemáticamente faz sentido ou não colocares o marcador com valores relativos para todo o tensor, faltam te dados impiricos, o volume pensas te inicialmnete deixar em impirico para o tensor para normalizares os tensores)
# * relative_second_marker = False, (tens de pensar em que marker correspondente estás a usar, pensa se matemáticamente faz sentido ou não colocares o marcador com valores relativos para todo o tensor, faltam te dados impiricos)
# * relative_third_marker = False, (tens de pensar em que marker correspondente estás a usar, pensa se matemáticamente faz sentido ou não colocares o marcador com valores relativos para todo o tensor, faltam te dados impiricos)
# * decimals = '', 3, 4 (tens de ver o que os dados impiricos te dizem se com arrendondamentos facilitas ou n a vida do AI)
# * LSTM = True, (em caso de falso não usas um LSTM e partes do precipio que a relação causal deixa de ser importante para a cosntrução do tensor, quando normalizas os dados a esperança seria de não teres de usar um LSTM)
# * epochs = 5, (este numero tende a ser irrelevante porque tens um checkpoint de callback referente ao melhor resultado de validation accuracy)
# * batch_size = 64, 16, 32, 128, 256, 512 (varias com o tramanho do dataset, mas pensa que tens conseguido datasets bem grandes portanto usa os maiores valores)

# %%
# Definir a função main
def main(symbol = 'NVDA', max_period = False, start_date = '', end_date = '', timeframe = '5Min', fisrt_marker = 'vwap', second_marker = 'trade_count',
         third_marker = '', n_rows = 36, sort = False, relative_first_marker = True, relative_second_marker = False,
         relative_third_marker = False, decimals = '', LSTM = True, epochs = 1000, batch_size = 128):

    company_data = get_all_data(symbol, max_period, start_date, end_date, timeframe)

    print(company_data)
    print(company_data.shape)
    print()

    company_data = prepare_data(company_data, fisrt_marker, second_marker, third_marker)

    print(company_data)
    print(company_data.shape)
    print()

    matrices_x, matrices_y = get_dataset(company_data, n_rows, sort, fisrt_marker, second_marker , third_marker, relative_first_marker, relative_second_marker, relative_third_marker, decimals)

    print(matrices_x)
    print(matrices_x.shape)
    print(matrices_y)
    print(matrices_y.shape)
    print()

    X_train, X_val, X_test, y_train, y_val, y_test = split_dataset(matrices_x, matrices_y, LSTM)

    # Exibir as formas dos arrays resultantes
    print("Shape of X_train:", X_train.shape)
    print("Shape of y_train:", y_train.shape)
    print("Shape of X_val:", X_val.shape)
    print("Shape of y_val:", y_val.shape)
    print("Shape of X_test:", X_test.shape)
    print("Shape of y_test:", y_test.shape)
    print()

    if third_marker == '':
        input_shape = (n_rows, 2)
    else:
        input_shape = (n_rows, 3)
    model = build_model(input_shape, LSTM)

    history, test_loss, test_accuracy = model_training(model, X_train, X_val, X_test, y_train, y_val, y_test, epochs, batch_size)
    print()

    graphics_analysis(history)

# Verificar se o script está sendo executado diretamente
if __name__ == "__main__":
     main(start_date = '2016-10-31', end_date = '2023-12-31')
# Out:
#                             close      high     low  trade_count     open  \
# timestamp
# 2016-10-31 08:05:00+00:00   70.60   70.6000   70.60            1   70.600
# 2016-10-31 08:10:00+00:00   70.60   70.6000   70.60            1   70.600
# 2016-10-31 08:15:00+00:00   70.60   70.6000   70.60            1   70.600
# 2016-10-31 09:10:00+00:00   70.60   70.6000   70.60            1   70.600
# 2016-10-31 10:25:00+00:00   70.28   70.2800   70.28            1   70.280
# ...                           ...       ...     ...          ...      ...
# 2023-12-30 00:35:00+00:00  493.69  493.8790  493.69           44  493.879
# 2023-12-30 00:40:00+00:00  493.78  493.7800  493.69           50  493.730
# 2023-12-30 00:45:00+00:00  493.67  493.8499  493.67           44  493.840
# 2023-12-30 00:50:00+00:00  493.50  493.6900  493.40          133  493.690
# 2023-12-30 00:55:00+00:00  493.30  493.5000  493.25          205  493.500
#
#                            volume        vwap
# timestamp
# 2016-10-31 08:05:00+00:00     140   70.600000
# 2016-10-31 08:10:00+00:00     500   70.600000
# 2016-10-31 08:15:00+00:00     360   70.600000
# 2016-10-31 09:10:00+00:00     140   70.600000
# 2016-10-31 10:25:00+00:00     100   70.280000
# ...                           ...         ...
# 2023-12-30 00:35:00+00:00    1478  493.726817
# 2023-12-30 00:40:00+00:00    2471  493.716865
# 2023-12-30 00:45:00+00:00    2318  493.711169
# 2023-12-30 00:50:00+00:00    6566  493.510847
# 2023-12-30 00:55:00+00:00   12163  493.349365
#
# [338585 rows x 7 columns]
# (338585, 7)
#
#                                  vwap  trade_count
# timestamp
# 2016-10-31 08:05:00+00:00   70.600000            1
# 2016-10-31 08:10:00+00:00   70.600000            1
# 2016-10-31 08:15:00+00:00   70.600000            1
# 2016-10-31 09:10:00+00:00   70.600000            1
# 2016-10-31 10:25:00+00:00   70.280000            1
# ...                               ...          ...
# 2023-12-30 00:35:00+00:00  493.726817           44
# 2023-12-30 00:40:00+00:00  493.716865           50
# 2023-12-30 00:45:00+00:00  493.711169           44
# 2023-12-30 00:50:00+00:00  493.510847          133
# 2023-12-30 00:55:00+00:00  493.349365          205
#
# [338585 rows x 2 columns]
# (338585, 2)
#
# [[[2.76422706e-02 1.00000000e+00]
#   [2.76422706e-02 1.00000000e+00]
#   [2.76422706e-02 1.00000000e+00]
#   ...
#   [2.77269401e-02 7.51000000e+02]
#   [2.77613739e-02 6.32000000e+02]
#   [2.77786574e-02 5.00000000e+02]]
#
#  [[2.76545009e-02 5.38000000e+02]
#   [2.76376896e-02 4.33000000e+02]
#   [2.76307222e-02 4.13000000e+02]
#   ...
#   [2.78337665e-02 5.88000000e+02]
#   [2.78585357e-02 6.40000000e+02]
#   [2.78598013e-02 6.94000000e+02]]
#
#  [[2.78051021e-02 4.50000000e+02]
#   [2.78087259e-02 7.94000000e+02]
#   [2.78244382e-02 9.94000000e+02]
#   ...
#   [2.79754746e-02 1.00000000e+00]
#   [2.78275798e-02 1.00000000e+00]
#   [2.78275798e-02 1.00000000e+00]]
#
#  ...
#
#  [[2.77425933e-02 1.08000000e+02]
#   [2.77472356e-02 7.20000000e+01]
#   [2.77425010e-02 9.30000000e+01]
#   ...
#   [2.78007462e-02 9.33400000e+03]
#   [2.78114115e-02 9.14200000e+03]
#   [2.77713630e-02 1.27590000e+04]]
#
#  [[2.80745055e-02 1.01520000e+04]
#   [2.79950274e-02 1.37760000e+04]
#   [2.78984230e-02 1.18280000e+04]
#   ...
#   [2.78998705e-02 2.99600000e+03]
#   [2.79246187e-02 3.76100000e+03]
#   [2.79477907e-02 3.71700000e+03]]
#
#  [[2.76777503e-02 6.26300000e+03]
#   [2.77066592e-02 3.70200000e+03]
#   [2.77300227e-02 6.11700000e+03]
#   ...
#   [2.76670012e-02 1.01000000e+02]
#   [2.76653737e-02 7.90000000e+01]
#   [2.76656071e-02 4.20000000e+01]]]
# (9404, 36, 2)
# [1 0 1 ... 0 0 0]
# (9404,)
#
# Shape of X_train: (5642, 36, 2)
# Shape of y_train: (5642,)
# Shape of X_val: (1880, 36, 2)
# Shape of y_val: (1880,)
# Shape of X_test: (1882, 36, 2)
# Shape of y_test: (1882,)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/rnn/rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 36, 64)              │          17,152 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 36, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 64)                  │          33,024 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 64)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 1)                   │              65 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 50,241 (196.25 KB)
#  Trainable params: 50,241 (196.25 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 108ms/step - accuracy: 0.7526 - loss: 0.5367 - val_accuracy: 0.7468 - val_loss: 0.5258
# Epoch 2/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - accuracy: 0.8035 - loss: 0.4572 - val_accuracy: 0.6856 - val_loss: 0.5772
# Epoch 3/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - accuracy: 0.8189 - loss: 0.4269 - val_accuracy: 0.7511 - val_loss: 0.4910
# Epoch 4/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 136ms/step - accuracy: 0.8283 - loss: 0.3932 - val_accuracy: 0.7043 - val_loss: 0.5426
# Epoch 5/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 105ms/step - accuracy: 0.8362 - loss: 0.3898 - val_accuracy: 0.6963 - val_loss: 0.5830
# Epoch 6/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - accuracy: 0.8397 - loss: 0.3858 - val_accuracy: 0.7016 - val_loss: 0.6169
# Epoch 7/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - accuracy: 0.8333 - loss: 0.3909 - val_accuracy: 0.6644 - val_loss: 0.6400
# Epoch 8/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 133ms/step - accuracy: 0.8385 - loss: 0.3847 - val_accuracy: 0.7426 - val_loss: 0.5232
# Epoch 9/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - accuracy: 0.8371 - loss: 0.3716 - val_accuracy: 0.7346 - val_loss: 0.5426
# Epoch 10/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 98ms/step - accuracy: 0.8427 - loss: 0.3598 - val_accuracy: 0.7069 - val_loss: 0.5598
# Epoch 11/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 133ms/step - accuracy: 0.8339 - loss: 0.3786 - val_accuracy: 0.7378 - val_loss: 0.5205
# Epoch 12/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - accuracy: 0.8508 - loss: 0.3509 - val_accuracy: 0.7255 - val_loss: 0.5410
# Epoch 13/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - accuracy: 0.8367 - loss: 0.3662 - val_accuracy: 0.7580 - val_loss: 0.5309
# Epoch 14/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 0.8479 - loss: 0.3560 - val_accuracy: 0.7404 - val_loss: 0.6096
# Epoch 15/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - accuracy: 0.8484 - loss: 0.3579 - val_accuracy: 0.7543 - val_loss: 0.5416
# Epoch 16/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - accuracy: 0.8406 - loss: 0.3735 - val_accuracy: 0.7447 - val_loss: 0.5497
# Epoch 17/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 99ms/step - accuracy: 0.8422 - loss: 0.3533 - val_accuracy: 0.7771 - val_loss: 0.4912
# Epoch 18/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.8483 - loss: 0.3512 - val_accuracy: 0.7745 - val_loss: 0.4733
# Epoch 19/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 131ms/step - accuracy: 0.8482 - loss: 0.3494 - val_accuracy: 0.7021 - val_loss: 0.6105
# Epoch 20/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - accuracy: 0.8505 - loss: 0.3505 - val_accuracy: 0.7457 - val_loss: 0.5620
# Epoch 21/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - accuracy: 0.8350 - loss: 0.3720 - val_accuracy: 0.7580 - val_loss: 0.5630
# Epoch 22/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 100ms/step - accuracy: 0.8393 - loss: 0.3677 - val_accuracy: 0.7596 - val_loss: 0.5297
# Epoch 23/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 136ms/step - accuracy: 0.8500 - loss: 0.3398 - val_accuracy: 0.7734 - val_loss: 0.5016
# Epoch 24/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 12s 168ms/step - accuracy: 0.8414 - loss: 0.3594 - val_accuracy: 0.7532 - val_loss: 0.5440
# Epoch 25/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 99ms/step - accuracy: 0.8408 - loss: 0.3572 - val_accuracy: 0.7569 - val_loss: 0.5402
# Epoch 26/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 133ms/step - accuracy: 0.8527 - loss: 0.3431 - val_accuracy: 0.7686 - val_loss: 0.5176
# Epoch 27/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 98ms/step - accuracy: 0.8454 - loss: 0.3491 - val_accuracy: 0.7516 - val_loss: 0.5438
# Epoch 28/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - accuracy: 0.8416 - loss: 0.3539 - val_accuracy: 0.7793 - val_loss: 0.5159
# Epoch 29/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 98ms/step - accuracy: 0.8545 - loss: 0.3380 - val_accuracy: 0.7590 - val_loss: 0.5608
# Epoch 30/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - accuracy: 0.8436 - loss: 0.3629 - val_accuracy: 0.7473 - val_loss: 0.5616
# Epoch 31/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - accuracy: 0.8487 - loss: 0.3508 - val_accuracy: 0.7335 - val_loss: 0.5701
# Epoch 32/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step - accuracy: 0.8481 - loss: 0.3479 - val_accuracy: 0.7399 - val_loss: 0.5915
# Epoch 33/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - accuracy: 0.8397 - loss: 0.3509 - val_accuracy: 0.7601 - val_loss: 0.5504
# Epoch 34/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - accuracy: 0.8502 - loss: 0.3365 - val_accuracy: 0.7144 - val_loss: 0.6569
# Epoch 35/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 137ms/step - accuracy: 0.8416 - loss: 0.3551 - val_accuracy: 0.7755 - val_loss: 0.5068
# Epoch 36/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - accuracy: 0.8481 - loss: 0.3460 - val_accuracy: 0.7388 - val_loss: 0.5363
# Epoch 37/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 132ms/step - accuracy: 0.8438 - loss: 0.3455 - val_accuracy: 0.7468 - val_loss: 0.5344
# Epoch 38/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - accuracy: 0.8443 - loss: 0.3486 - val_accuracy: 0.7580 - val_loss: 0.5188
# Epoch 39/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 135ms/step - accuracy: 0.8474 - loss: 0.3432 - val_accuracy: 0.7516 - val_loss: 0.5252
# Epoch 40/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - accuracy: 0.8473 - loss: 0.3381 - val_accuracy: 0.7761 - val_loss: 0.4860
# Epoch 41/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 132ms/step - accuracy: 0.8451 - loss: 0.3430 - val_accuracy: 0.7606 - val_loss: 0.5160
# Epoch 42/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 124ms/step - accuracy: 0.8485 - loss: 0.3358 - val_accuracy: 0.7165 - val_loss: 0.6269
# Epoch 43/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - accuracy: 0.8513 - loss: 0.3453 - val_accuracy: 0.7351 - val_loss: 0.5852
# Epoch 44/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.8418 - loss: 0.3623 - val_accuracy: 0.7415 - val_loss: 0.5723
# Epoch 45/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - accuracy: 0.8445 - loss: 0.3437 - val_accuracy: 0.7564 - val_loss: 0.5300
# Epoch 46/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - accuracy: 0.8372 - loss: 0.3577 - val_accuracy: 0.7755 - val_loss: 0.4997
# Epoch 47/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - accuracy: 0.8522 - loss: 0.3399 - val_accuracy: 0.7612 - val_loss: 0.5402
# Epoch 48/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 152ms/step - accuracy: 0.8443 - loss: 0.3442 - val_accuracy: 0.7559 - val_loss: 0.5477
# Epoch 49/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 99ms/step - accuracy: 0.8492 - loss: 0.3412 - val_accuracy: 0.7676 - val_loss: 0.5390
# Epoch 50/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 134ms/step - accuracy: 0.8462 - loss: 0.3537 - val_accuracy: 0.8011 - val_loss: 0.4567
# Epoch 51/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - accuracy: 0.8445 - loss: 0.3457 - val_accuracy: 0.7346 - val_loss: 0.5834
# Epoch 52/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 133ms/step - accuracy: 0.8444 - loss: 0.3381 - val_accuracy: 0.7527 - val_loss: 0.5718
# Epoch 53/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - accuracy: 0.8436 - loss: 0.3442 - val_accuracy: 0.7601 - val_loss: 0.5387
# Epoch 54/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 114ms/step - accuracy: 0.8576 - loss: 0.3277 - val_accuracy: 0.7734 - val_loss: 0.5351
# Epoch 55/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.8543 - loss: 0.3381 - val_accuracy: 0.7351 - val_loss: 0.6024
# Epoch 56/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 135ms/step - accuracy: 0.8407 - loss: 0.3396 - val_accuracy: 0.7463 - val_loss: 0.5942
# Epoch 57/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - accuracy: 0.8468 - loss: 0.3370 - val_accuracy: 0.7798 - val_loss: 0.5149
# Epoch 58/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.8582 - loss: 0.3314 - val_accuracy: 0.7590 - val_loss: 0.5591
# Epoch 59/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - accuracy: 0.8553 - loss: 0.3263 - val_accuracy: 0.7824 - val_loss: 0.5087
# Epoch 60/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 104ms/step - accuracy: 0.8602 - loss: 0.3199 - val_accuracy: 0.7718 - val_loss: 0.5430
# Epoch 61/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.8551 - loss: 0.3269 - val_accuracy: 0.7537 - val_loss: 0.5527
# Epoch 62/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 136ms/step - accuracy: 0.8459 - loss: 0.3387 - val_accuracy: 0.7665 - val_loss: 0.6089
# Epoch 63/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - accuracy: 0.8516 - loss: 0.3333 - val_accuracy: 0.7367 - val_loss: 0.6016
# Epoch 64/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 134ms/step - accuracy: 0.8489 - loss: 0.3357 - val_accuracy: 0.7580 - val_loss: 0.5492
# Epoch 65/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - accuracy: 0.8576 - loss: 0.3287 - val_accuracy: 0.7484 - val_loss: 0.5960
# Epoch 66/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.8450 - loss: 0.3329 - val_accuracy: 0.7649 - val_loss: 0.5428
# Epoch 67/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.8525 - loss: 0.3269 - val_accuracy: 0.7282 - val_loss: 0.6739
# Epoch 68/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 137ms/step - accuracy: 0.8569 - loss: 0.3224 - val_accuracy: 0.7745 - val_loss: 0.5657
# Epoch 69/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - accuracy: 0.8528 - loss: 0.3166 - val_accuracy: 0.7516 - val_loss: 0.5815
# Epoch 70/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 140ms/step - accuracy: 0.8613 - loss: 0.3228 - val_accuracy: 0.7495 - val_loss: 0.5788
# Epoch 71/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 100ms/step - accuracy: 0.8654 - loss: 0.3093 - val_accuracy: 0.7606 - val_loss: 0.5666
# Epoch 72/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 155ms/step - accuracy: 0.8558 - loss: 0.3230 - val_accuracy: 0.7569 - val_loss: 0.5994
# Epoch 73/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 127ms/step - accuracy: 0.8598 - loss: 0.3152 - val_accuracy: 0.7399 - val_loss: 0.6249
# Epoch 74/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - accuracy: 0.8605 - loss: 0.3091 - val_accuracy: 0.7543 - val_loss: 0.5834
# Epoch 75/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 136ms/step - accuracy: 0.8521 - loss: 0.3366 - val_accuracy: 0.7399 - val_loss: 0.6034
# Epoch 76/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - accuracy: 0.8547 - loss: 0.3239 - val_accuracy: 0.7723 - val_loss: 0.5291
# Epoch 77/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 135ms/step - accuracy: 0.8560 - loss: 0.3267 - val_accuracy: 0.7654 - val_loss: 0.5409
# Epoch 78/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.8568 - loss: 0.3196 - val_accuracy: 0.7388 - val_loss: 0.6123
# Epoch 79/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 134ms/step - accuracy: 0.8607 - loss: 0.3091 - val_accuracy: 0.8053 - val_loss: 0.4772
# Epoch 80/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - accuracy: 0.8573 - loss: 0.3210 - val_accuracy: 0.6995 - val_loss: 0.7355
# Epoch 81/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - accuracy: 0.8611 - loss: 0.3219 - val_accuracy: 0.7729 - val_loss: 0.5598
# Epoch 82/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - accuracy: 0.8593 - loss: 0.3070 - val_accuracy: 0.7745 - val_loss: 0.5505
# Epoch 83/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 117ms/step - accuracy: 0.8517 - loss: 0.3229 - val_accuracy: 0.7399 - val_loss: 0.6373
# Epoch 84/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 100ms/step - accuracy: 0.8588 - loss: 0.3103 - val_accuracy: 0.7824 - val_loss: 0.5267
# Epoch 85/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 136ms/step - accuracy: 0.8654 - loss: 0.3070 - val_accuracy: 0.7665 - val_loss: 0.5856
# Epoch 86/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.8592 - loss: 0.3081 - val_accuracy: 0.7452 - val_loss: 0.6034
# Epoch 87/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 113ms/step - accuracy: 0.8497 - loss: 0.3361 - val_accuracy: 0.7894 - val_loss: 0.4931
# Epoch 88/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.8502 - loss: 0.3322 - val_accuracy: 0.7670 - val_loss: 0.5856
# Epoch 89/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - accuracy: 0.8550 - loss: 0.3253 - val_accuracy: 0.7803 - val_loss: 0.5341
# Epoch 90/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 136ms/step - accuracy: 0.8578 - loss: 0.3161 - val_accuracy: 0.7707 - val_loss: 0.5458
# Epoch 91/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - accuracy: 0.8598 - loss: 0.3142 - val_accuracy: 0.7495 - val_loss: 0.6220
# Epoch 92/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.8619 - loss: 0.3101 - val_accuracy: 0.7995 - val_loss: 0.5001
# Epoch 93/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 132ms/step - accuracy: 0.8641 - loss: 0.3089 - val_accuracy: 0.7590 - val_loss: 0.5975
# Epoch 94/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 124ms/step - accuracy: 0.8585 - loss: 0.3041 - val_accuracy: 0.7707 - val_loss: 0.5364
# Epoch 95/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - accuracy: 0.8520 - loss: 0.3257 - val_accuracy: 0.7936 - val_loss: 0.5127
# Epoch 96/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step - accuracy: 0.8645 - loss: 0.3040 - val_accuracy: 0.7899 - val_loss: 0.5035
# Epoch 97/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 99ms/step - accuracy: 0.8592 - loss: 0.3074 - val_accuracy: 0.7899 - val_loss: 0.5201
# Epoch 98/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 130ms/step - accuracy: 0.8639 - loss: 0.3047 - val_accuracy: 0.7777 - val_loss: 0.5242
# Epoch 99/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.8686 - loss: 0.3090 - val_accuracy: 0.7665 - val_loss: 0.5580
# Epoch 100/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - accuracy: 0.8615 - loss: 0.3077 - val_accuracy: 0.7691 - val_loss: 0.5547
# Epoch 101/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - accuracy: 0.8649 - loss: 0.2988 - val_accuracy: 0.7580 - val_loss: 0.5705
# Epoch 102/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.8623 - loss: 0.2986 - val_accuracy: 0.7835 - val_loss: 0.5105
# Epoch 103/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step - accuracy: 0.8624 - loss: 0.2944 - val_accuracy: 0.7585 - val_loss: 0.5869
# Epoch 104/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - accuracy: 0.8647 - loss: 0.3030 - val_accuracy: 0.7824 - val_loss: 0.5293
# Epoch 105/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.8597 - loss: 0.3092 - val_accuracy: 0.7750 - val_loss: 0.5298
# Epoch 106/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - accuracy: 0.8731 - loss: 0.2806 - val_accuracy: 0.7867 - val_loss: 0.5500
# Epoch 107/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 140ms/step - accuracy: 0.8669 - loss: 0.2906 - val_accuracy: 0.7761 - val_loss: 0.5452
# Epoch 108/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - accuracy: 0.8608 - loss: 0.2959 - val_accuracy: 0.7846 - val_loss: 0.5344
# Epoch 109/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.8651 - loss: 0.2952 - val_accuracy: 0.7761 - val_loss: 0.5442
# Epoch 110/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - accuracy: 0.8649 - loss: 0.2903 - val_accuracy: 0.7649 - val_loss: 0.5960
# Epoch 111/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - accuracy: 0.8675 - loss: 0.2916 - val_accuracy: 0.7511 - val_loss: 0.6055
# Epoch 112/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 99ms/step - accuracy: 0.8700 - loss: 0.2761 - val_accuracy: 0.7059 - val_loss: 0.6843
# Epoch 113/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 133ms/step - accuracy: 0.8700 - loss: 0.2838 - val_accuracy: 0.7798 - val_loss: 0.5665
# Epoch 114/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - accuracy: 0.8644 - loss: 0.2973 - val_accuracy: 0.7846 - val_loss: 0.5419
# Epoch 115/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.8670 - loss: 0.3056 - val_accuracy: 0.6936 - val_loss: 0.6868
# Epoch 116/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - accuracy: 0.8559 - loss: 0.3281 - val_accuracy: 0.7213 - val_loss: 0.6283
# Epoch 117/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - accuracy: 0.8511 - loss: 0.3251 - val_accuracy: 0.7654 - val_loss: 0.5381
# Epoch 118/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - accuracy: 0.8627 - loss: 0.3107 - val_accuracy: 0.7856 - val_loss: 0.5031
# Epoch 119/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 114ms/step - accuracy: 0.8631 - loss: 0.3054 - val_accuracy: 0.7718 - val_loss: 0.5488
# Epoch 120/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.8592 - loss: 0.3125 - val_accuracy: 0.7819 - val_loss: 0.5726
# Epoch 121/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.8594 - loss: 0.3109 - val_accuracy: 0.7856 - val_loss: 0.5388
# Epoch 122/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.8677 - loss: 0.2911 - val_accuracy: 0.7819 - val_loss: 0.5329
# Epoch 123/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - accuracy: 0.8670 - loss: 0.2947 - val_accuracy: 0.7862 - val_loss: 0.5223
# Epoch 124/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - accuracy: 0.8686 - loss: 0.2803 - val_accuracy: 0.7644 - val_loss: 0.5839
# Epoch 125/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 136ms/step - accuracy: 0.8628 - loss: 0.2886 - val_accuracy: 0.7532 - val_loss: 0.6153
# Epoch 126/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 126ms/step - accuracy: 0.8708 - loss: 0.2897 - val_accuracy: 0.7941 - val_loss: 0.5432
# Epoch 127/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - accuracy: 0.8651 - loss: 0.2930 - val_accuracy: 0.7176 - val_loss: 0.6755
# Epoch 128/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - accuracy: 0.8679 - loss: 0.2890 - val_accuracy: 0.7559 - val_loss: 0.5888
# Epoch 129/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 120ms/step - accuracy: 0.8679 - loss: 0.2866 - val_accuracy: 0.7553 - val_loss: 0.5892
# Epoch 130/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 102ms/step - accuracy: 0.8667 - loss: 0.2892 - val_accuracy: 0.7644 - val_loss: 0.6134
# Epoch 131/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.8730 - loss: 0.2810 - val_accuracy: 0.7691 - val_loss: 0.5809
# Epoch 132/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 105ms/step - accuracy: 0.8722 - loss: 0.2743 - val_accuracy: 0.7638 - val_loss: 0.5747
# Epoch 133/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 143ms/step - accuracy: 0.8689 - loss: 0.2819 - val_accuracy: 0.7574 - val_loss: 0.6050
# Epoch 134/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 102ms/step - accuracy: 0.8784 - loss: 0.2720 - val_accuracy: 0.7590 - val_loss: 0.6230
# Epoch 135/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.8688 - loss: 0.2829 - val_accuracy: 0.7670 - val_loss: 0.5798
# Epoch 136/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - accuracy: 0.8749 - loss: 0.2687 - val_accuracy: 0.7755 - val_loss: 0.5747
# Epoch 137/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 131ms/step - accuracy: 0.8747 - loss: 0.2751 - val_accuracy: 0.7559 - val_loss: 0.6503
# Epoch 138/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 109ms/step - accuracy: 0.8652 - loss: 0.2911 - val_accuracy: 0.7617 - val_loss: 0.6138
# Epoch 139/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.8733 - loss: 0.2770 - val_accuracy: 0.7755 - val_loss: 0.5606
# Epoch 140/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 141ms/step - accuracy: 0.8653 - loss: 0.2936 - val_accuracy: 0.7707 - val_loss: 0.5771
# Epoch 141/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 101ms/step - accuracy: 0.8720 - loss: 0.2783 - val_accuracy: 0.7691 - val_loss: 0.5832
# Epoch 142/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.8743 - loss: 0.2692 - val_accuracy: 0.7835 - val_loss: 0.5446
# Epoch 143/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 136ms/step - accuracy: 0.8776 - loss: 0.2665 - val_accuracy: 0.7963 - val_loss: 0.5465
# Epoch 144/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 104ms/step - accuracy: 0.8736 - loss: 0.2719 - val_accuracy: 0.7894 - val_loss: 0.5532
# Epoch 145/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 104ms/step - accuracy: 0.8798 - loss: 0.2659 - val_accuracy: 0.7862 - val_loss: 0.5682
# Epoch 146/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 140ms/step - accuracy: 0.8777 - loss: 0.2637 - val_accuracy: 0.7356 - val_loss: 0.6812
# Epoch 147/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - accuracy: 0.8774 - loss: 0.2613 - val_accuracy: 0.7543 - val_loss: 0.6153
# Epoch 148/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 133ms/step - accuracy: 0.8771 - loss: 0.2667 - val_accuracy: 0.7564 - val_loss: 0.6325
# Epoch 149/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - accuracy: 0.8627 - loss: 0.2884 - val_accuracy: 0.7574 - val_loss: 0.6035
# Epoch 150/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.8820 - loss: 0.2584 - val_accuracy: 0.7660 - val_loss: 0.5802
# Epoch 151/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - accuracy: 0.8774 - loss: 0.2699 - val_accuracy: 0.7447 - val_loss: 0.6014
# Epoch 152/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - accuracy: 0.8743 - loss: 0.2731 - val_accuracy: 0.7878 - val_loss: 0.5297
# Epoch 153/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 132ms/step - accuracy: 0.8783 - loss: 0.2675 - val_accuracy: 0.7899 - val_loss: 0.5450
# Epoch 154/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 128ms/step - accuracy: 0.8806 - loss: 0.2575 - val_accuracy: 0.7867 - val_loss: 0.5806
# Epoch 155/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - accuracy: 0.8798 - loss: 0.2665 - val_accuracy: 0.7798 - val_loss: 0.6294
# Epoch 156/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.8801 - loss: 0.2514 - val_accuracy: 0.7862 - val_loss: 0.5749
# Epoch 157/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 101ms/step - accuracy: 0.8832 - loss: 0.2459 - val_accuracy: 0.7872 - val_loss: 0.5701
# Epoch 158/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 133ms/step - accuracy: 0.8743 - loss: 0.2665 - val_accuracy: 0.7782 - val_loss: 0.6007
# Epoch 159/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.8822 - loss: 0.2531 - val_accuracy: 0.7670 - val_loss: 0.6166
# Epoch 160/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.8749 - loss: 0.2535 - val_accuracy: 0.7734 - val_loss: 0.6036
# Epoch 161/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - accuracy: 0.8762 - loss: 0.2543 - val_accuracy: 0.7915 - val_loss: 0.5614
# Epoch 162/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - accuracy: 0.8823 - loss: 0.2567 - val_accuracy: 0.7686 - val_loss: 0.6138
# Epoch 163/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 136ms/step - accuracy: 0.8779 - loss: 0.2666 - val_accuracy: 0.7809 - val_loss: 0.5665
# Epoch 164/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 101ms/step - accuracy: 0.8814 - loss: 0.2586 - val_accuracy: 0.7606 - val_loss: 0.6152
# Epoch 165/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 130ms/step - accuracy: 0.8709 - loss: 0.2733 - val_accuracy: 0.7633 - val_loss: 0.6309
# Epoch 166/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.8810 - loss: 0.2611 - val_accuracy: 0.7814 - val_loss: 0.5671
# Epoch 167/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 101ms/step - accuracy: 0.8894 - loss: 0.2493 - val_accuracy: 0.7968 - val_loss: 0.5437
# Epoch 168/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 141ms/step - accuracy: 0.8907 - loss: 0.2470 - val_accuracy: 0.7888 - val_loss: 0.5627
# Epoch 169/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 4s 100ms/step - accuracy: 0.8851 - loss: 0.2394 - val_accuracy: 0.7447 - val_loss: 0.6993
# Epoch 170/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 118ms/step - accuracy: 0.8855 - loss: 0.2439 - val_accuracy: 0.7697 - val_loss: 0.6091
# Epoch 171/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 101ms/step - accuracy: 0.8805 - loss: 0.2508 - val_accuracy: 0.7670 - val_loss: 0.6584
# Epoch 172/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 139ms/step - accuracy: 0.8867 - loss: 0.2528 - val_accuracy: 0.7426 - val_loss: 0.6728
# Epoch 173/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 133ms/step - accuracy: 0.8838 - loss: 0.2535 - val_accuracy: 0.7729 - val_loss: 0.6369
# Epoch 174/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 101ms/step - accuracy: 0.8842 - loss: 0.2467 - val_accuracy: 0.7862 - val_loss: 0.6021
# Epoch 175/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - accuracy: 0.8804 - loss: 0.2517 - val_accuracy: 0.7729 - val_loss: 0.6474
# Epoch 176/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.8816 - loss: 0.2461 - val_accuracy: 0.7495 - val_loss: 0.7049
# Epoch 177/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.8779 - loss: 0.2650 - val_accuracy: 0.7745 - val_loss: 0.6462
# Epoch 178/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 121ms/step - accuracy: 0.8876 - loss: 0.2442 - val_accuracy: 0.7803 - val_loss: 0.6040
# Epoch 179/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 102ms/step - accuracy: 0.8835 - loss: 0.2415 - val_accuracy: 0.7739 - val_loss: 0.6388
# Epoch 180/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 142ms/step - accuracy: 0.8851 - loss: 0.2443 - val_accuracy: 0.7649 - val_loss: 0.6815
# Epoch 181/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.8794 - loss: 0.2491 - val_accuracy: 0.7500 - val_loss: 0.7004
# Epoch 182/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.8935 - loss: 0.2388 - val_accuracy: 0.7553 - val_loss: 0.6874
# Epoch 183/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 105ms/step - accuracy: 0.8857 - loss: 0.2416 - val_accuracy: 0.7851 - val_loss: 0.5724
# Epoch 184/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 134ms/step - accuracy: 0.8871 - loss: 0.2406 - val_accuracy: 0.7803 - val_loss: 0.6299
# Epoch 185/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 121ms/step - accuracy: 0.8848 - loss: 0.2521 - val_accuracy: 0.7670 - val_loss: 0.6544
# Epoch 186/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.8948 - loss: 0.2269 - val_accuracy: 0.7548 - val_loss: 0.7181
# Epoch 187/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 144ms/step - accuracy: 0.8975 - loss: 0.2375 - val_accuracy: 0.7787 - val_loss: 0.6090
# Epoch 188/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.8871 - loss: 0.2417 - val_accuracy: 0.7713 - val_loss: 0.6112
# Epoch 189/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.8883 - loss: 0.2304 - val_accuracy: 0.7713 - val_loss: 0.6331
# Epoch 190/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - accuracy: 0.8777 - loss: 0.2455 - val_accuracy: 0.7723 - val_loss: 0.6564
# Epoch 191/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 111ms/step - accuracy: 0.8738 - loss: 0.2615 - val_accuracy: 0.7787 - val_loss: 0.6482
# Epoch 192/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.8843 - loss: 0.2580 - val_accuracy: 0.7750 - val_loss: 0.6580
# Epoch 193/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 141ms/step - accuracy: 0.8943 - loss: 0.2306 - val_accuracy: 0.7484 - val_loss: 0.7468
# Epoch 194/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.8874 - loss: 0.2377 - val_accuracy: 0.7644 - val_loss: 0.7032
# Epoch 195/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.8909 - loss: 0.2435 - val_accuracy: 0.7564 - val_loss: 0.7093
# Epoch 196/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 137ms/step - accuracy: 0.8918 - loss: 0.2279 - val_accuracy: 0.7463 - val_loss: 0.7461
# Epoch 197/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 123ms/step - accuracy: 0.8897 - loss: 0.2374 - val_accuracy: 0.7824 - val_loss: 0.6350
# Epoch 198/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 148ms/step - accuracy: 0.8904 - loss: 0.2367 - val_accuracy: 0.7723 - val_loss: 0.6524
# Epoch 199/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - accuracy: 0.8936 - loss: 0.2319 - val_accuracy: 0.7644 - val_loss: 0.6955
# Epoch 200/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 139ms/step - accuracy: 0.8716 - loss: 0.2563 - val_accuracy: 0.7803 - val_loss: 0.6534
# Epoch 201/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - accuracy: 0.8849 - loss: 0.2527 - val_accuracy: 0.7830 - val_loss: 0.6716
# Epoch 202/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.8855 - loss: 0.2573 - val_accuracy: 0.7707 - val_loss: 0.6924
# Epoch 203/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 102ms/step - accuracy: 0.8910 - loss: 0.2289 - val_accuracy: 0.7468 - val_loss: 0.7417
# Epoch 204/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 143ms/step - accuracy: 0.8913 - loss: 0.2297 - val_accuracy: 0.7569 - val_loss: 0.7229
# Epoch 205/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.8964 - loss: 0.2245 - val_accuracy: 0.7809 - val_loss: 0.6623
# Epoch 206/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - accuracy: 0.8914 - loss: 0.2257 - val_accuracy: 0.7830 - val_loss: 0.6388
# Epoch 207/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 102ms/step - accuracy: 0.8883 - loss: 0.2229 - val_accuracy: 0.7468 - val_loss: 0.7592
# Epoch 208/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 135ms/step - accuracy: 0.8913 - loss: 0.2237 - val_accuracy: 0.7681 - val_loss: 0.7246
# Epoch 209/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - accuracy: 0.8854 - loss: 0.2365 - val_accuracy: 0.7654 - val_loss: 0.7385
# Epoch 210/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 129ms/step - accuracy: 0.8926 - loss: 0.2159 - val_accuracy: 0.7745 - val_loss: 0.6987
# Epoch 211/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 138ms/step - accuracy: 0.8832 - loss: 0.2479 - val_accuracy: 0.7596 - val_loss: 0.6437
# Epoch 212/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 104ms/step - accuracy: 0.8709 - loss: 0.2777 - val_accuracy: 0.7819 - val_loss: 0.5747
# Epoch 213/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 145ms/step - accuracy: 0.8861 - loss: 0.2438 - val_accuracy: 0.7777 - val_loss: 0.6098
# Epoch 214/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.8889 - loss: 0.2337 - val_accuracy: 0.7484 - val_loss: 0.7490
# Epoch 215/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 116ms/step - accuracy: 0.8812 - loss: 0.2527 - val_accuracy: 0.7559 - val_loss: 0.7077
# Epoch 216/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 132ms/step - accuracy: 0.9026 - loss: 0.2216 - val_accuracy: 0.7660 - val_loss: 0.6645
# Epoch 217/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - accuracy: 0.8993 - loss: 0.2231 - val_accuracy: 0.7686 - val_loss: 0.6802
# Epoch 218/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - accuracy: 0.8953 - loss: 0.2210 - val_accuracy: 0.7654 - val_loss: 0.7409
# Epoch 219/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 105ms/step - accuracy: 0.8976 - loss: 0.2204 - val_accuracy: 0.7856 - val_loss: 0.6624
# Epoch 220/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 139ms/step - accuracy: 0.8978 - loss: 0.2251 - val_accuracy: 0.7739 - val_loss: 0.6713
# Epoch 221/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.8962 - loss: 0.2293 - val_accuracy: 0.7665 - val_loss: 0.7397
# Epoch 222/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 134ms/step - accuracy: 0.8932 - loss: 0.2200 - val_accuracy: 0.7713 - val_loss: 0.6977
# Epoch 223/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 141ms/step - accuracy: 0.8992 - loss: 0.2145 - val_accuracy: 0.7755 - val_loss: 0.7013
# Epoch 224/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 102ms/step - accuracy: 0.8952 - loss: 0.2221 - val_accuracy: 0.7691 - val_loss: 0.6954
# Epoch 225/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.8937 - loss: 0.2282 - val_accuracy: 0.7638 - val_loss: 0.7514
# Epoch 226/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 109ms/step - accuracy: 0.8981 - loss: 0.2238 - val_accuracy: 0.7702 - val_loss: 0.7094
# Epoch 227/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.8927 - loss: 0.2262 - val_accuracy: 0.7697 - val_loss: 0.7329
# Epoch 228/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - accuracy: 0.8979 - loss: 0.2156 - val_accuracy: 0.7697 - val_loss: 0.7312
# Epoch 229/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 126ms/step - accuracy: 0.8967 - loss: 0.2222 - val_accuracy: 0.7543 - val_loss: 0.7635
# Epoch 230/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 104ms/step - accuracy: 0.8955 - loss: 0.2195 - val_accuracy: 0.7739 - val_loss: 0.6343
# Epoch 231/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 145ms/step - accuracy: 0.8960 - loss: 0.2214 - val_accuracy: 0.7574 - val_loss: 0.7345
# Epoch 232/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 104ms/step - accuracy: 0.9005 - loss: 0.2056 - val_accuracy: 0.7601 - val_loss: 0.7458
# Epoch 233/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 128ms/step - accuracy: 0.9007 - loss: 0.2070 - val_accuracy: 0.7484 - val_loss: 0.8480
# Epoch 234/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 104ms/step - accuracy: 0.8460 - loss: 0.3538 - val_accuracy: 0.7638 - val_loss: 0.6333
# Epoch 235/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 147ms/step - accuracy: 0.8716 - loss: 0.2732 - val_accuracy: 0.7606 - val_loss: 0.6610
# Epoch 236/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 104ms/step - accuracy: 0.8769 - loss: 0.2522 - val_accuracy: 0.7479 - val_loss: 0.7185
# Epoch 237/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 129ms/step - accuracy: 0.8940 - loss: 0.2384 - val_accuracy: 0.7569 - val_loss: 0.7034
# Epoch 238/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 104ms/step - accuracy: 0.8942 - loss: 0.2342 - val_accuracy: 0.7606 - val_loss: 0.6890
# Epoch 239/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 137ms/step - accuracy: 0.9027 - loss: 0.2245 - val_accuracy: 0.7670 - val_loss: 0.6565
# Epoch 240/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - accuracy: 0.8993 - loss: 0.2204 - val_accuracy: 0.7686 - val_loss: 0.6792
# Epoch 241/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.9021 - loss: 0.2097 - val_accuracy: 0.7505 - val_loss: 0.7533
# Epoch 242/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 134ms/step - accuracy: 0.8980 - loss: 0.2204 - val_accuracy: 0.7771 - val_loss: 0.6707
# Epoch 243/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 129ms/step - accuracy: 0.9022 - loss: 0.2133 - val_accuracy: 0.7686 - val_loss: 0.7207
# Epoch 244/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 104ms/step - accuracy: 0.8915 - loss: 0.2307 - val_accuracy: 0.7601 - val_loss: 0.7368
# Epoch 245/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 139ms/step - accuracy: 0.9021 - loss: 0.2177 - val_accuracy: 0.7729 - val_loss: 0.6794
# Epoch 246/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 100ms/step - accuracy: 0.9035 - loss: 0.2141 - val_accuracy: 0.7612 - val_loss: 0.7625
# Epoch 247/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 166ms/step - accuracy: 0.8914 - loss: 0.2290 - val_accuracy: 0.7745 - val_loss: 0.6844
# Epoch 248/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 137ms/step - accuracy: 0.8984 - loss: 0.2210 - val_accuracy: 0.7569 - val_loss: 0.7803
# Epoch 249/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - accuracy: 0.8992 - loss: 0.2236 - val_accuracy: 0.7553 - val_loss: 0.6992
# Epoch 250/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 100ms/step - accuracy: 0.8962 - loss: 0.2221 - val_accuracy: 0.7644 - val_loss: 0.7238
# Epoch 251/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 134ms/step - accuracy: 0.8996 - loss: 0.2165 - val_accuracy: 0.7559 - val_loss: 0.7821
# Epoch 252/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 119ms/step - accuracy: 0.9093 - loss: 0.2000 - val_accuracy: 0.7612 - val_loss: 0.7737
# Epoch 253/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 100ms/step - accuracy: 0.9043 - loss: 0.2044 - val_accuracy: 0.7691 - val_loss: 0.7364
# Epoch 254/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.9002 - loss: 0.2091 - val_accuracy: 0.7660 - val_loss: 0.7398
# Epoch 255/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - accuracy: 0.8969 - loss: 0.2102 - val_accuracy: 0.7713 - val_loss: 0.7039
# Epoch 256/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step - accuracy: 0.9094 - loss: 0.1988 - val_accuracy: 0.7840 - val_loss: 0.7115
# Epoch 257/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 136ms/step - accuracy: 0.9024 - loss: 0.2163 - val_accuracy: 0.7670 - val_loss: 0.7358
# Epoch 258/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 129ms/step - accuracy: 0.9077 - loss: 0.1999 - val_accuracy: 0.7665 - val_loss: 0.7366
# Epoch 259/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 113ms/step - accuracy: 0.9110 - loss: 0.1979 - val_accuracy: 0.7787 - val_loss: 0.7132
# Epoch 260/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 142ms/step - accuracy: 0.9055 - loss: 0.1946 - val_accuracy: 0.7803 - val_loss: 0.6859
# Epoch 261/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 103ms/step - accuracy: 0.9070 - loss: 0.1957 - val_accuracy: 0.7649 - val_loss: 0.7786
# Epoch 262/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.9083 - loss: 0.1946 - val_accuracy: 0.7638 - val_loss: 0.7655
# Epoch 263/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.8983 - loss: 0.2088 - val_accuracy: 0.7660 - val_loss: 0.7772
# Epoch 264/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 122ms/step - accuracy: 0.9149 - loss: 0.1898 - val_accuracy: 0.7787 - val_loss: 0.7584
# Epoch 265/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 103ms/step - accuracy: 0.9086 - loss: 0.1994 - val_accuracy: 0.7532 - val_loss: 0.7790
# Epoch 266/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 144ms/step - accuracy: 0.8995 - loss: 0.2115 - val_accuracy: 0.7718 - val_loss: 0.7839
# Epoch 267/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.9005 - loss: 0.2102 - val_accuracy: 0.7676 - val_loss: 0.7979
# Epoch 268/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.9056 - loss: 0.1971 - val_accuracy: 0.7691 - val_loss: 0.7754
# Epoch 269/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 103ms/step - accuracy: 0.9055 - loss: 0.2146 - val_accuracy: 0.7691 - val_loss: 0.8045
# Epoch 270/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 143ms/step - accuracy: 0.9015 - loss: 0.2049 - val_accuracy: 0.7660 - val_loss: 0.8041
# Epoch 271/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 102ms/step - accuracy: 0.9054 - loss: 0.2028 - val_accuracy: 0.7750 - val_loss: 0.7650
# Epoch 272/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 161ms/step - accuracy: 0.9038 - loss: 0.2072 - val_accuracy: 0.7596 - val_loss: 0.8077
# Epoch 273/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - accuracy: 0.9113 - loss: 0.1953 - val_accuracy: 0.7670 - val_loss: 0.7731
# Epoch 274/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 140ms/step - accuracy: 0.9122 - loss: 0.1976 - val_accuracy: 0.7755 - val_loss: 0.7713
# Epoch 275/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 103ms/step - accuracy: 0.9078 - loss: 0.1954 - val_accuracy: 0.7787 - val_loss: 0.7417
# Epoch 276/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 141ms/step - accuracy: 0.9155 - loss: 0.1905 - val_accuracy: 0.7633 - val_loss: 0.8388
# Epoch 277/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 128ms/step - accuracy: 0.9063 - loss: 0.1950 - val_accuracy: 0.7851 - val_loss: 0.7339
# Epoch 278/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - accuracy: 0.9037 - loss: 0.2043 - val_accuracy: 0.7644 - val_loss: 0.7844
# Epoch 279/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 139ms/step - accuracy: 0.9044 - loss: 0.2035 - val_accuracy: 0.7649 - val_loss: 0.7771
# Epoch 280/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 102ms/step - accuracy: 0.8999 - loss: 0.2050 - val_accuracy: 0.7681 - val_loss: 0.7552
# Epoch 281/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 145ms/step - accuracy: 0.9035 - loss: 0.1992 - val_accuracy: 0.7644 - val_loss: 0.8633
# Epoch 282/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 116ms/step - accuracy: 0.9079 - loss: 0.2042 - val_accuracy: 0.7681 - val_loss: 0.8359
# Epoch 283/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 102ms/step - accuracy: 0.9084 - loss: 0.2003 - val_accuracy: 0.7835 - val_loss: 0.7801
# Epoch 284/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 146ms/step - accuracy: 0.9075 - loss: 0.1930 - val_accuracy: 0.7702 - val_loss: 0.7996
# Epoch 285/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 103ms/step - accuracy: 0.9090 - loss: 0.1997 - val_accuracy: 0.7622 - val_loss: 0.8532
# Epoch 286/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 142ms/step - accuracy: 0.8924 - loss: 0.2187 - val_accuracy: 0.7713 - val_loss: 0.8235
# Epoch 287/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 104ms/step - accuracy: 0.9093 - loss: 0.1946 - val_accuracy: 0.7601 - val_loss: 0.8453
# Epoch 288/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 133ms/step - accuracy: 0.9093 - loss: 0.1880 - val_accuracy: 0.7718 - val_loss: 0.7952
# Epoch 289/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.9005 - loss: 0.2228 - val_accuracy: 0.7644 - val_loss: 0.7905
# Epoch 290/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - accuracy: 0.9042 - loss: 0.2105 - val_accuracy: 0.7729 - val_loss: 0.7735
# Epoch 291/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - accuracy: 0.9009 - loss: 0.2033 - val_accuracy: 0.7660 - val_loss: 0.8034
# Epoch 292/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.9034 - loss: 0.2107 - val_accuracy: 0.7676 - val_loss: 0.7725
# Epoch 293/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - accuracy: 0.9098 - loss: 0.1970 - val_accuracy: 0.7904 - val_loss: 0.7205
# Epoch 294/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - accuracy: 0.9077 - loss: 0.1967 - val_accuracy: 0.7644 - val_loss: 0.7901
# Epoch 295/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 104ms/step - accuracy: 0.9125 - loss: 0.1837 - val_accuracy: 0.7649 - val_loss: 0.8280
# Epoch 296/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 176ms/step - accuracy: 0.9185 - loss: 0.1786 - val_accuracy: 0.7463 - val_loss: 0.9059
# Epoch 297/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 104ms/step - accuracy: 0.9050 - loss: 0.1981 - val_accuracy: 0.7580 - val_loss: 0.8369
# Epoch 298/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 132ms/step - accuracy: 0.9113 - loss: 0.1840 - val_accuracy: 0.7660 - val_loss: 0.7941
# Epoch 299/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.9142 - loss: 0.1878 - val_accuracy: 0.7617 - val_loss: 0.8408
# Epoch 300/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 105ms/step - accuracy: 0.9086 - loss: 0.2044 - val_accuracy: 0.7723 - val_loss: 0.7844
# Epoch 301/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step - accuracy: 0.9046 - loss: 0.2041 - val_accuracy: 0.7585 - val_loss: 0.8060
# Epoch 302/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 103ms/step - accuracy: 0.9084 - loss: 0.1986 - val_accuracy: 0.7612 - val_loss: 0.8333
# Epoch 303/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.9103 - loss: 0.1893 - val_accuracy: 0.7686 - val_loss: 0.8125
# Epoch 304/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 104ms/step - accuracy: 0.9189 - loss: 0.1825 - val_accuracy: 0.7819 - val_loss: 0.7620
# Epoch 305/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 147ms/step - accuracy: 0.9095 - loss: 0.1956 - val_accuracy: 0.7644 - val_loss: 0.7873
# Epoch 306/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 104ms/step - accuracy: 0.9155 - loss: 0.1806 - val_accuracy: 0.7691 - val_loss: 0.8092
# Epoch 307/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 140ms/step - accuracy: 0.9116 - loss: 0.1899 - val_accuracy: 0.7622 - val_loss: 0.8476
# Epoch 308/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 133ms/step - accuracy: 0.9070 - loss: 0.1963 - val_accuracy: 0.7649 - val_loss: 0.8226
# Epoch 309/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 105ms/step - accuracy: 0.9141 - loss: 0.1856 - val_accuracy: 0.7580 - val_loss: 0.8817
# Epoch 310/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 145ms/step - accuracy: 0.9129 - loss: 0.1926 - val_accuracy: 0.7543 - val_loss: 0.9110
# Epoch 311/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 107ms/step - accuracy: 0.9154 - loss: 0.1778 - val_accuracy: 0.7559 - val_loss: 0.8054
# Epoch 312/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - accuracy: 0.8970 - loss: 0.2234 - val_accuracy: 0.7697 - val_loss: 0.8559
# Epoch 313/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.8734 - loss: 0.2942 - val_accuracy: 0.7718 - val_loss: 0.7618
# Epoch 314/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 148ms/step - accuracy: 0.9050 - loss: 0.2154 - val_accuracy: 0.7830 - val_loss: 0.7630
# Epoch 315/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 121ms/step - accuracy: 0.9011 - loss: 0.2226 - val_accuracy: 0.7628 - val_loss: 0.8543
# Epoch 316/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 121ms/step - accuracy: 0.9126 - loss: 0.1854 - val_accuracy: 0.7564 - val_loss: 0.8556
# Epoch 317/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 121ms/step - accuracy: 0.9129 - loss: 0.1901 - val_accuracy: 0.7670 - val_loss: 0.7859
# Epoch 318/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 13s 175ms/step - accuracy: 0.9106 - loss: 0.1929 - val_accuracy: 0.7676 - val_loss: 0.8333
# Epoch 319/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 136ms/step - accuracy: 0.9182 - loss: 0.1848 - val_accuracy: 0.7691 - val_loss: 0.7780
# Epoch 320/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - accuracy: 0.9144 - loss: 0.1823 - val_accuracy: 0.7686 - val_loss: 0.8168
# Epoch 321/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 166ms/step - accuracy: 0.9125 - loss: 0.1826 - val_accuracy: 0.7739 - val_loss: 0.7532
# Epoch 322/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 124ms/step - accuracy: 0.9086 - loss: 0.1915 - val_accuracy: 0.7569 - val_loss: 0.9450
# Epoch 323/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 166ms/step - accuracy: 0.9227 - loss: 0.1794 - val_accuracy: 0.7612 - val_loss: 0.8883
# Epoch 324/1000
# ...
# Epoch 460/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 104ms/step - accuracy: 0.9196 - loss: 0.1761 - val_accuracy: 0.7266 - val_loss: 1.0841
# Epoch 461/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 147ms/step - accuracy: 0.9223 - loss: 0.1718 - val_accuracy: 0.7553 - val_loss: 0.9367
# Epoch 462/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 105ms/step - accuracy: 0.9247 - loss: 0.1672 - val_accuracy: 0.7596 - val_loss: 0.9384
# Epoch 463/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.9294 - loss: 0.1657 - val_accuracy: 0.7511 - val_loss: 0.9590
# Epoch 464/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 138ms/step - accuracy: 0.9222 - loss: 0.1651 - val_accuracy: 0.7473 - val_loss: 1.0321
# Epoch 465/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.9189 - loss: 0.1768 - val_accuracy: 0.7457 - val_loss: 1.0469
# Epoch 466/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.9217 - loss: 0.1749 - val_accuracy: 0.7649 - val_loss: 0.9155
# Epoch 467/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 123ms/step - accuracy: 0.9183 - loss: 0.1876 - val_accuracy: 0.7527 - val_loss: 0.9306
# Epoch 468/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 105ms/step - accuracy: 0.9227 - loss: 0.1692 - val_accuracy: 0.7596 - val_loss: 0.9185
# Epoch 469/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 140ms/step - accuracy: 0.9199 - loss: 0.1740 - val_accuracy: 0.7569 - val_loss: 0.9922
# Epoch 470/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 105ms/step - accuracy: 0.9195 - loss: 0.1751 - val_accuracy: 0.7495 - val_loss: 1.0199
# Epoch 471/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.9218 - loss: 0.1748 - val_accuracy: 0.7479 - val_loss: 0.9890
# Epoch 472/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.9274 - loss: 0.1668 - val_accuracy: 0.7468 - val_loss: 1.0390
# Epoch 473/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 150ms/step - accuracy: 0.9219 - loss: 0.1710 - val_accuracy: 0.7372 - val_loss: 1.1069
# Epoch 474/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 104ms/step - accuracy: 0.9230 - loss: 0.1675 - val_accuracy: 0.7484 - val_loss: 1.0728
# Epoch 475/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.9252 - loss: 0.1704 - val_accuracy: 0.7559 - val_loss: 0.9933
# Epoch 476/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 129ms/step - accuracy: 0.9299 - loss: 0.1656 - val_accuracy: 0.7452 - val_loss: 1.0465
# Epoch 477/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 144ms/step - accuracy: 0.9266 - loss: 0.1670 - val_accuracy: 0.7463 - val_loss: 1.0820
# Epoch 478/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 104ms/step - accuracy: 0.9216 - loss: 0.1717 - val_accuracy: 0.7564 - val_loss: 0.9721
# Epoch 479/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - accuracy: 0.9195 - loss: 0.1751 - val_accuracy: 0.7399 - val_loss: 1.1289
# Epoch 480/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 104ms/step - accuracy: 0.9150 - loss: 0.1907 - val_accuracy: 0.7527 - val_loss: 1.0040
# Epoch 481/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 136ms/step - accuracy: 0.9168 - loss: 0.1922 - val_accuracy: 0.7479 - val_loss: 1.0609
# Epoch 482/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.9168 - loss: 0.1714 - val_accuracy: 0.7346 - val_loss: 1.0960
# Epoch 483/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 144ms/step - accuracy: 0.9221 - loss: 0.1713 - val_accuracy: 0.7537 - val_loss: 1.0485
# Epoch 484/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 105ms/step - accuracy: 0.9204 - loss: 0.1795 - val_accuracy: 0.7399 - val_loss: 1.0258
# Epoch 485/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 143ms/step - accuracy: 0.9260 - loss: 0.1680 - val_accuracy: 0.7431 - val_loss: 1.0252
# Epoch 486/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 104ms/step - accuracy: 0.9254 - loss: 0.1604 - val_accuracy: 0.7271 - val_loss: 1.1461
# Epoch 487/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 143ms/step - accuracy: 0.9230 - loss: 0.1707 - val_accuracy: 0.7282 - val_loss: 1.1676
# Epoch 488/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.9267 - loss: 0.1609 - val_accuracy: 0.7410 - val_loss: 1.0290
# Epoch 489/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 131ms/step - accuracy: 0.9213 - loss: 0.1694 - val_accuracy: 0.7463 - val_loss: 1.0875
# Epoch 490/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 153ms/step - accuracy: 0.9297 - loss: 0.1499 - val_accuracy: 0.7441 - val_loss: 1.0611
# Epoch 491/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 132ms/step - accuracy: 0.9277 - loss: 0.1641 - val_accuracy: 0.7484 - val_loss: 1.0097
# Epoch 492/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 147ms/step - accuracy: 0.9244 - loss: 0.1580 - val_accuracy: 0.7532 - val_loss: 1.0452
# Epoch 493/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 105ms/step - accuracy: 0.9277 - loss: 0.1550 - val_accuracy: 0.7612 - val_loss: 1.0302
# Epoch 494/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.9309 - loss: 0.1551 - val_accuracy: 0.7548 - val_loss: 1.0035
# Epoch 495/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.9382 - loss: 0.1449 - val_accuracy: 0.7489 - val_loss: 1.0369
# Epoch 496/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step - accuracy: 0.9216 - loss: 0.1732 - val_accuracy: 0.7484 - val_loss: 1.0254
# Epoch 497/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.9297 - loss: 0.1555 - val_accuracy: 0.7473 - val_loss: 1.0472
# Epoch 498/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 145ms/step - accuracy: 0.9228 - loss: 0.1718 - val_accuracy: 0.7574 - val_loss: 0.9609
# Epoch 499/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.9253 - loss: 0.1750 - val_accuracy: 0.7564 - val_loss: 1.0206
# Epoch 500/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 104ms/step - accuracy: 0.9418 - loss: 0.1432 - val_accuracy: 0.7484 - val_loss: 1.0027
# Epoch 501/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 145ms/step - accuracy: 0.9229 - loss: 0.1748 - val_accuracy: 0.7548 - val_loss: 0.9497
# Epoch 502/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.9265 - loss: 0.1638 - val_accuracy: 0.7431 - val_loss: 1.0347
# Epoch 503/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 138ms/step - accuracy: 0.9270 - loss: 0.1551 - val_accuracy: 0.7484 - val_loss: 1.0487
# Epoch 504/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 104ms/step - accuracy: 0.9225 - loss: 0.1589 - val_accuracy: 0.7362 - val_loss: 1.0768
# Epoch 505/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 143ms/step - accuracy: 0.9325 - loss: 0.1647 - val_accuracy: 0.7527 - val_loss: 1.0725
# Epoch 506/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 104ms/step - accuracy: 0.9284 - loss: 0.1605 - val_accuracy: 0.7489 - val_loss: 1.1000
# Epoch 507/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 147ms/step - accuracy: 0.9226 - loss: 0.1581 - val_accuracy: 0.7532 - val_loss: 1.0899
# Epoch 508/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 104ms/step - accuracy: 0.9257 - loss: 0.1653 - val_accuracy: 0.7340 - val_loss: 1.1597
# Epoch 509/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.9258 - loss: 0.1687 - val_accuracy: 0.7489 - val_loss: 1.1064
# Epoch 510/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 122ms/step - accuracy: 0.9275 - loss: 0.1605 - val_accuracy: 0.7548 - val_loss: 1.0512
# Epoch 511/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 141ms/step - accuracy: 0.9273 - loss: 0.1708 - val_accuracy: 0.7473 - val_loss: 1.0256
# Epoch 512/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 106ms/step - accuracy: 0.9283 - loss: 0.1650 - val_accuracy: 0.7543 - val_loss: 0.9986
# Epoch 513/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 147ms/step - accuracy: 0.9372 - loss: 0.1487 - val_accuracy: 0.7489 - val_loss: 0.9971
# Epoch 514/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 105ms/step - accuracy: 0.9298 - loss: 0.1621 - val_accuracy: 0.7489 - val_loss: 1.0076
# Epoch 515/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 134ms/step - accuracy: 0.9241 - loss: 0.1591 - val_accuracy: 0.7521 - val_loss: 1.0438
# Epoch 516/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 107ms/step - accuracy: 0.9408 - loss: 0.1448 - val_accuracy: 0.7468 - val_loss: 1.1052
# Epoch 517/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 140ms/step - accuracy: 0.9330 - loss: 0.1538 - val_accuracy: 0.7495 - val_loss: 1.0738
# Epoch 518/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 105ms/step - accuracy: 0.9318 - loss: 0.1563 - val_accuracy: 0.7500 - val_loss: 1.1351
# Epoch 519/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 145ms/step - accuracy: 0.9242 - loss: 0.1631 - val_accuracy: 0.7559 - val_loss: 1.0953
# Epoch 520/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.9364 - loss: 0.1483 - val_accuracy: 0.7388 - val_loss: 1.2028
# Epoch 521/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.9255 - loss: 0.1553 - val_accuracy: 0.7473 - val_loss: 1.1433
# Epoch 522/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 105ms/step - accuracy: 0.9369 - loss: 0.1472 - val_accuracy: 0.7383 - val_loss: 1.2582
# Epoch 523/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 142ms/step - accuracy: 0.9316 - loss: 0.1460 - val_accuracy: 0.7447 - val_loss: 1.1744
# Epoch 524/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 107ms/step - accuracy: 0.9311 - loss: 0.1524 - val_accuracy: 0.7543 - val_loss: 1.1380
# Epoch 525/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 146ms/step - accuracy: 0.9301 - loss: 0.1545 - val_accuracy: 0.7479 - val_loss: 1.1333
# Epoch 526/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 106ms/step - accuracy: 0.9274 - loss: 0.1510 - val_accuracy: 0.7580 - val_loss: 1.1098
# Epoch 527/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 141ms/step - accuracy: 0.9318 - loss: 0.1551 - val_accuracy: 0.7511 - val_loss: 1.1287
# Epoch 528/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 110ms/step - accuracy: 0.9310 - loss: 0.1484 - val_accuracy: 0.7367 - val_loss: 1.1655
# Epoch 529/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 107ms/step - accuracy: 0.9270 - loss: 0.1552 - val_accuracy: 0.7303 - val_loss: 1.2001
# Epoch 530/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 150ms/step - accuracy: 0.9343 - loss: 0.1499 - val_accuracy: 0.7314 - val_loss: 1.1694
# Epoch 531/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - accuracy: 0.9321 - loss: 0.1473 - val_accuracy: 0.7612 - val_loss: 1.0585
# Epoch 532/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 118ms/step - accuracy: 0.9307 - loss: 0.1566 - val_accuracy: 0.7293 - val_loss: 1.2350
# Epoch 533/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 139ms/step - accuracy: 0.9289 - loss: 0.1712 - val_accuracy: 0.7319 - val_loss: 1.1825
# Epoch 534/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 116ms/step - accuracy: 0.9308 - loss: 0.1596 - val_accuracy: 0.7399 - val_loss: 1.1523
# Epoch 535/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 116ms/step - accuracy: 0.9265 - loss: 0.1662 - val_accuracy: 0.7314 - val_loss: 1.2199
# Epoch 536/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 122ms/step - accuracy: 0.9385 - loss: 0.1355 - val_accuracy: 0.7277 - val_loss: 1.2114
# Epoch 537/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 12s 161ms/step - accuracy: 0.9347 - loss: 0.1515 - val_accuracy: 0.7473 - val_loss: 1.1061
# Epoch 538/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - accuracy: 0.9261 - loss: 0.1618 - val_accuracy: 0.7617 - val_loss: 1.0689
# Epoch 539/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 171ms/step - accuracy: 0.9281 - loss: 0.1637 - val_accuracy: 0.7553 - val_loss: 1.0224
# Epoch 540/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 145ms/step - accuracy: 0.9253 - loss: 0.1679 - val_accuracy: 0.7282 - val_loss: 1.1058
# Epoch 541/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 161ms/step - accuracy: 0.9304 - loss: 0.1584 - val_accuracy: 0.7527 - val_loss: 1.0731
# Epoch 542/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 117ms/step - accuracy: 0.9311 - loss: 0.1504 - val_accuracy: 0.7548 - val_loss: 1.0973
# Epoch 543/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 155ms/step - accuracy: 0.9318 - loss: 0.1477 - val_accuracy: 0.7463 - val_loss: 1.1375
# Epoch 544/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - accuracy: 0.9292 - loss: 0.1609 - val_accuracy: 0.7309 - val_loss: 1.2074
# Epoch 545/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 119ms/step - accuracy: 0.9294 - loss: 0.1483 - val_accuracy: 0.7479 - val_loss: 1.1309
# Epoch 546/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 133ms/step - accuracy: 0.9318 - loss: 0.1539 - val_accuracy: 0.7489 - val_loss: 1.0989
# Epoch 547/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 12s 165ms/step - accuracy: 0.9435 - loss: 0.1319 - val_accuracy: 0.7495 - val_loss: 1.1065
# Epoch 548/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 115ms/step - accuracy: 0.9276 - loss: 0.1597 - val_accuracy: 0.7553 - val_loss: 1.0710
# Epoch 549/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 154ms/step - accuracy: 0.9297 - loss: 0.1455 - val_accuracy: 0.7410 - val_loss: 1.0621
# Epoch 550/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 118ms/step - accuracy: 0.9270 - loss: 0.1544 - val_accuracy: 0.7335 - val_loss: 1.2121
# Epoch 551/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 12s 156ms/step - accuracy: 0.9266 - loss: 0.1573 - val_accuracy: 0.7606 - val_loss: 1.0764
# Epoch 552/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 143ms/step - accuracy: 0.9308 - loss: 0.1585 - val_accuracy: 0.7468 - val_loss: 1.1396
# Epoch 553/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.9338 - loss: 0.1488 - val_accuracy: 0.7654 - val_loss: 1.0928
# Epoch 554/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 12s 161ms/step - accuracy: 0.9388 - loss: 0.1488 - val_accuracy: 0.7537 - val_loss: 1.1302
# Epoch 555/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 135ms/step - accuracy: 0.9351 - loss: 0.1482 - val_accuracy: 0.7537 - val_loss: 1.1426
# Epoch 556/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 145ms/step - accuracy: 0.9317 - loss: 0.1560 - val_accuracy: 0.7431 - val_loss: 1.1957
# Epoch 557/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 162ms/step - accuracy: 0.9306 - loss: 0.1508 - val_accuracy: 0.7500 - val_loss: 1.1962
# Epoch 558/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - accuracy: 0.9384 - loss: 0.1397 - val_accuracy: 0.7447 - val_loss: 1.1691
# Epoch 559/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 141ms/step - accuracy: 0.9278 - loss: 0.1505 - val_accuracy: 0.7431 - val_loss: 1.2464
# Epoch 560/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 136ms/step - accuracy: 0.9370 - loss: 0.1477 - val_accuracy: 0.7388 - val_loss: 1.1685
# Epoch 561/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - accuracy: 0.9258 - loss: 0.1668 - val_accuracy: 0.7383 - val_loss: 1.1469
# Epoch 562/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 199ms/step - accuracy: 0.9307 - loss: 0.1631 - val_accuracy: 0.7404 - val_loss: 1.2565
# Epoch 563/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 119ms/step - accuracy: 0.9334 - loss: 0.1529 - val_accuracy: 0.7394 - val_loss: 1.2216
# Epoch 564/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 164ms/step - accuracy: 0.9268 - loss: 0.1639 - val_accuracy: 0.7410 - val_loss: 1.2056
# Epoch 565/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - accuracy: 0.9334 - loss: 0.1470 - val_accuracy: 0.7335 - val_loss: 1.2215
# Epoch 566/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 168ms/step - accuracy: 0.9371 - loss: 0.1413 - val_accuracy: 0.7319 - val_loss: 1.2167
# Epoch 567/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 111ms/step - accuracy: 0.9305 - loss: 0.1670 - val_accuracy: 0.7404 - val_loss: 1.2219
# Epoch 568/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 150ms/step - accuracy: 0.9340 - loss: 0.1445 - val_accuracy: 0.7324 - val_loss: 1.2327
# Epoch 569/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 132ms/step - accuracy: 0.9389 - loss: 0.1450 - val_accuracy: 0.7378 - val_loss: 1.2474
# Epoch 570/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 6s 127ms/step - accuracy: 0.9332 - loss: 0.1547 - val_accuracy: 0.7521 - val_loss: 1.1655
# Epoch 571/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 11s 152ms/step - accuracy: 0.9331 - loss: 0.1516 - val_accuracy: 0.7559 - val_loss: 1.1603
# Epoch 572/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 8s 111ms/step - accuracy: 0.9377 - loss: 0.1423 - val_accuracy: 0.7527 - val_loss: 1.1232
# Epoch 573/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 147ms/step - accuracy: 0.9384 - loss: 0.1362 - val_accuracy: 0.7511 - val_loss: 1.2066
# Epoch 574/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 141ms/step - accuracy: 0.9352 - loss: 0.1452 - val_accuracy: 0.7452 - val_loss: 1.2095
# Epoch 575/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - accuracy: 0.9413 - loss: 0.1308 - val_accuracy: 0.7399 - val_loss: 1.2107
# Epoch 576/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 10s 108ms/step - accuracy: 0.9311 - loss: 0.1547 - val_accuracy: 0.7399 - val_loss: 1.2197
# Epoch 577/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 7s 150ms/step - accuracy: 0.9335 - loss: 0.1492 - val_accuracy: 0.7452 - val_loss: 1.2314
# Epoch 578/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 111ms/step - accuracy: 0.9381 - loss: 0.1382 - val_accuracy: 0.7415 - val_loss: 1.2122
# Epoch 579/1000
# 45/45 ━━━━━━━━━━━━━━━━━━━━ 5s 117ms/step - accuracy: 0.9355 - loss: 0.1451 - val_accuracy: 0.7436 - val_loss: 1.2466
#
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - accuracy: 0.7984 - loss: 0.4625
